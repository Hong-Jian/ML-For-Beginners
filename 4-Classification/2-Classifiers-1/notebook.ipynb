# %%
import pandas as pd

cuisines_df  = pd.read_csv("../data/new_cuisines.csv")

label_df = cuisines_df['cuisine']
feature_df = cuisines_df.drop(['cuisine', 'Unnamed: 0'], axis=1)
label_df
# Out:
# 0       indian
# 1       indian
# 2       indian
# 3       indian
# 4       indian
#          ...
# 3990      thai
# 3991      thai
# 3992      thai
# 3993      thai
# 3994      thai
# Name: cuisine, Length: 3995, dtype: object

# %%
from imblearn.over_sampling import SMOTE
